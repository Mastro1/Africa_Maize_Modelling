# %%
import geopandas as gpd

africa = gpd.read_file("gadm41_AFR_2.shp")

africa.tail(20)
# Out:
#             GID_2 GID_0    NAME_0     GID_1              NAME_1 NL_NAME_1  \
# 6595    ZWE.9.5_2   ZWE  Zimbabwe   ZWE.9_1  Matabeleland South        NA
# 6596    ZWE.9.6_2   ZWE  Zimbabwe   ZWE.9_1  Matabeleland South        NA
# 6597    ZWE.9.7_2   ZWE  Zimbabwe   ZWE.9_1  Matabeleland South        NA
# 6598    ZWE.9.8_2   ZWE  Zimbabwe   ZWE.9_1  Matabeleland South        NA
# 6599    ZWE.9.9_2   ZWE  Zimbabwe   ZWE.9_1  Matabeleland South        NA
# 6600   ZWE.9.10_2   ZWE  Zimbabwe   ZWE.9_1  Matabeleland South        NA
# 6601   ZWE.10.1_2   ZWE  Zimbabwe  ZWE.10_1            Midlands        NA
# 6602   ZWE.10.2_2   ZWE  Zimbabwe  ZWE.10_1            Midlands        NA
# 6603   ZWE.10.3_2   ZWE  Zimbabwe  ZWE.10_1            Midlands        NA
# 6604   ZWE.10.4_2   ZWE  Zimbabwe  ZWE.10_1            Midlands        NA
# 6605   ZWE.10.5_2   ZWE  Zimbabwe  ZWE.10_1            Midlands        NA
# 6606   ZWE.10.6_2   ZWE  Zimbabwe  ZWE.10_1            Midlands        NA
# ...

# %%
zambia = africa[africa['ADMIN0'] == 'Algeria']
# Out:
# <Axes: >
