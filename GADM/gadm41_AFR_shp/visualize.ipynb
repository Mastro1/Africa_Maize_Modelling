# %%
import geopandas as gpd

africa = gpd.read_file("GADM\gadm41_AFR_shp\gadm41_AFR_2.shp")

africa.plot(color='#240B60', figsize=(10, 10))
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\g'
# <>:3: SyntaxWarning: invalid escape sequence '\g'
# C:\Users\MassimoPoretti\AppData\Local\Temp\ipykernel_31008\3686917052.py:3: SyntaxWarning: invalid escape sequence '\g'
#   africa = gpd.read_file("GADM\gadm41_AFR_shp\gadm41_AFR_2.shp")
# <Axes: >

# %%
zambia = africa[africa['ADMIN0'] == 'Algeria']
# Out:
# <Axes: >
